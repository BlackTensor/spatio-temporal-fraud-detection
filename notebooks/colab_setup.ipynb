# %% [markdown]
# # Colab / Kaggle Setup — Spatio-Temporal Heterogeneous GNN
#
# Free GPU runner for this project. Works on **Google Colab** (Runtime → Change runtime type → GPU) and **Kaggle Notebooks** (Settings → Accelerator → GPU).
#
# This was developed on a Windows-on-ARM laptop with **no local NVIDIA GPU**, so all GNN training happens here for free. Run the cells top to bottom.

# %% [markdown]
# ## 1. Check the free GPU

# %%
# !nvidia-smi

# %% [markdown]
# ## 2. Install dependencies
#
# Colab/Kaggle ship PyTorch + CUDA preinstalled. We install PyTorch Geometric against the runtime's torch build, plus the project's lighter deps.

# %%
import torch
print('torch:', torch.__version__, '| CUDA available:', torch.cuda.is_available())

# Install PyG built against the active torch+CUDA version.
TORCH = torch.__version__.split('+')[0]
CUDA = 'cu' + torch.version.cuda.replace('.', '') if torch.cuda.is_available() else 'cpu'
print(f'Installing PyG wheels for torch-{TORCH}+{CUDA}')

# !pip -q install torch-geometric==2.6.1
# !pip -q install pyg-lib torch-scatter torch-sparse -f https://data.pyg.org/whl/torch-{TORCH}+{CUDA}.html
# !pip -q install xgboost shap umap-learn pyyaml

# %% [markdown]
# ## 3. Clone the repo

# %%
# Replace with your repo URL after pushing to GitHub.
REPO_URL = 'https://github.com/<your-username>/spatio-temporal-fraud-detection.git'

import os
if not os.path.isdir('spatio-temporal-fraud-detection'):
    # !git clone $REPO_URL
# %cd spatio-temporal-fraud-detection
# !ls

# %% [markdown]
# ## 4. (Optional) Kaggle API for free datasets
#
# Upload your `kaggle.json` (Kaggle → Account → Create New API Token). **Never commit it.**

# %%
# from google.colab import files; files.upload()  # pick kaggle.json
# !mkdir -p ~/.kaggle && cp kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# !pip -q install kaggle
# Example (Phase 1): download the Elliptic dataset
# !kaggle datasets download -d ellipticco/elliptic-data-set -p data/raw --unzip

# %% [markdown]
# ## 5. Sanity check
#
# Confirm PyG imports and a tensor lands on the GPU.

# %%
import torch, torch_geometric
from torch_geometric.data import HeteroData
print('torch_geometric:', torch_geometric.__version__)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
x = torch.randn(3, 4, device=device)
print('tensor device:', x.device)
print('Setup OK — ready to train.')
